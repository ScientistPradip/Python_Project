# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#Data Loading
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Cleanup Data /converting it into datetime format
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.tail()
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# 785736   Pekerjaan tetap               False       Singapore
# 785737   Pekerjaan tetap               False         Germany
# 785738   Pekerjaan tetap               False        Malaysia
# 785739   Pekerjaan tetap               False           Sudan
# 785740   Pekerjaan tetap               False           India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 785736   Singapore         NaN              NaN              NaN
# 785737     Germany         NaN              NaN              NaN
# 785738    Malaysia         NaN              NaN              NaN
# 785739       Sudan         NaN              NaN              NaN
# 785740       India         NaN              NaN              NaN
#
#                               company_name  \
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}

# %%
df.sample(6)
# Out:
#              job_title_short  \
# 648590        Data Scientist
# 25577           Data Analyst
# 306413         Data Engineer
# 667134        Data Scientist
# 121456         Data Engineer
# 367832  Senior Data Engineer
#
#                                                 job_title  \
# 648590                Científico de Datos/ Data Scientist
# 25577   M-Tech Data Analyst. Job in Edinburgh My Valle...
# 306413                             data engineer advanced
# 667134                                     Data Scientist
# 121456                               Gis Data Engineer Ii
# 367832      Senior Data Migration Technical Engineer/Lead
#
#                           job_location                   job_via  \
# 648590                      Lima, Peru                 via BeBee
# 25577                    Edinburgh, UK  via My Valley Jobs Today
# 306413  Centenario, Neuquen, Argentina                 via BeBee
# 667134                   Paris, France              via LinkedIn
# 121456              Guanajuato, Mexico                 via BeBee
# 367832      Johannesburg, South Africa        via Energy Jobline
#
#        job_schedule_type  job_work_from_home search_location  \
# 648590         Full-time               False            Peru
# 25577          Full-time               False  United Kingdom
# 306413         Full-time               False       Argentina
# 667134        Internship               False          France
# 121456         Full-time               False          Mexico
# 367832         Full-time               False    South Africa
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 648590 2023-10-11 12:11:57                  False                 False
# 25577  2023-01-24 13:16:49                   True                 False
# 306413 2023-03-02 17:42:10                  False                 False
# 667134 2023-01-10 10:29:34                  False                 False
# 121456 2023-10-05 08:17:28                  False                 False
# 367832 2023-07-17 23:56:28                   True                 False
#
#            job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 648590            Peru         NaN              NaN              NaN
# 25577   United Kingdom         NaN              NaN              NaN
# 306413       Argentina         NaN              NaN              NaN
# 667134          France         NaN              NaN              NaN
# 121456          Mexico         NaN              NaN              NaN
# 367832    South Africa         NaN              NaN              NaN
#
#               company_name                                         job_skills  \
# 648590             Emprego  ['sql', 'python', 'r', 'sql server', 'oracle',...
# 25577       Aviagen UK Ltd                                          ['excel']
# 306413                 BCP  ['python', 'sql', 'nosql', 'sql server', 'orac...
# 667134  MEGA International                                ['python', 'azure']
# 121456   HERE Technologies                          ['python', 'sql', 'flow']
# 367832          H2R Africa                                          ['azure']
#
#                                           job_type_skills
# 648590  {'analyst_tools': ['tableau', 'power bi'], 'cl...
# 25577                        {'analyst_tools': ['excel']}
# 306413  {'async': ['jira'], 'cloud': ['oracle'], 'data...
# 667134    {'cloud': ['azure'], 'programming': ['python']}
# 121456  {'other': ['flow'], 'programming': ['python', ...
# 367832                               {'cloud': ['azure']}

# %% [markdown]
# Copy() method

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
median_salary = df_altered['salary_year_avg'].median()
median_salary
# Out:
# np.float64(115000.0)

# %%
df_altered['salary_year_avg']= df_altered['salary_year_avg'].fillna(median_salary)
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
id(df_original)
# Out:
# 2143648545104

# %%
id(df_altered)
# Out:
# 2143648545104

# %%
id(df_original) == id(df_altered)
# Out:
# True

# %% [markdown]
# now using copy method to solve this issue

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original.copy()

# %%
print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                2143648537200
# ID of df_altered:                 2143648535072
# Are the two dataframes the same?  False

# %%
median_salary = df_altered['salary_year_avg'].median()
df_altered['salary_year_avg']= df_altered['salary_year_avg'].fillna(median_salary)
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64
